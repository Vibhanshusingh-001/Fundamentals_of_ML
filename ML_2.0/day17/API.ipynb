# %%
import pandas as pd
import requests

# %%
reasponse = requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=b36cc53d7edd1ba2afde3ac60d1ed1fb&language=en-US&page=1")

# %%
df = pd.DataFrame(reasponse.json()["results"])

# %%
df
# Out:
#     adult                     backdrop_path        genre_ids       id  \
# 0   False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg         [18, 80]      278
# 1   False  /tSPT36ZKlP2WVHJLM4cQPLSzv3b.jpg         [18, 80]      238
# 2   False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg         [18, 80]      240
# 3   False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg  [18, 36, 10752]      424
# 4   False  /w4bTBXcqXc2TUyS5Fc4h67uWbPn.jpg             [18]      389
# 5   False  /dyJvKsNs2KP8qQnAXbRwDjblViy.jpg  [16, 10751, 14]      129
# 6   False  /cfT29Im5VDvjE0RpyKOSdCKZal7.jpg     [28, 80, 53]      155
# 7   False  /6N5d02quKqMKqvTpOdFmBDy9scY.jpg  [35, 18, 10749]    19404
# 8   False  /b6HWTOxn1xevvyHU2K9ICvaRU6g.jpg     [14, 18, 80]      497
# 9   False  /2u7zbn8EudG6kLlBzUYqP8RyFU4.jpg     [12, 14, 28]      122
# 10  False   /TU9NIjwzjoKPwQHoHshkFcQUCG.jpg     [35, 53, 18]   496243
# 11  False  /suaEOtk1N1sgg2MTM7oZd2cfVp3.jpg     [53, 80, 35]      680
# ...

# %%
import pandas as pd
import requests

df = pd.DataFrame()

for i in range(1, 429):

    response = requests.get(
        'https://api.themoviedb.org/3/movie/top_rated?api_key=b36cc53d7edd1ba2afde3ac60d1ed1fb&language=en-US&page={}'.format(i)
    )

    temp_df = pd.DataFrame(response.json()['results'])[
        ['id', 'title', 'overview', 'release_date',
         'popularity', 'vote_average', 'vote_count']
    ]

    df = pd.concat([df, temp_df], ignore_index=True)

print(df.head())
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     52.3376
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     41.5315
# 2  In the continuing saga of the Corleone crime f...   1974-12-20     27.3249
# 3  The true story of how businessman Oskar Schind...   1993-12-15     26.9609
# 4  The defense and the prosecution have rested an...   1957-04-10     22.9436
#
#    vote_average  vote_count
# 0         8.719       30265
# 1         8.686       22852
# 2         8.571       13857
# 3         8.568       17392
# 4         8.560        9940

# %%
# try rapid api to get the data
